# %%
import pandas as pd
from datetime import datetime   
import matplotlib.pyplot as plt   
import matplotlib.font_manager as fm
import numpy as np
plt.rcParams["figure.figsize"] = (25, 11)

# %%
font_path = r'C:\Users\user\Desktop\폰트\Seoulnamsan_ttf\서울남산 장체L.ttf'
fontprop = fm.FontProperties(fname=font_path, size=18)

# %%
df = pd.read_csv('./data/df.csv') #2017-2021 구,연도,월,폐업,영업
cf = pd.read_csv('./data/cfdata.csv') #전체 카페 데이터
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
cf = cf.drop(['Unnamed: 0'],axis=1)
df = df.drop(['Unnamed: 0'],axis=1)

# %%
cf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26545 entries, 0 to 26544
# Data columns (total 58 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   APVPERMYMD   26545 non-null  object
#  1   TRDSTATEGBN  26545 non-null  int64
#  2   TRDSTATENM   26545 non-null  object
#  3   DCBYMD       10145 non-null  object
#  4   SITEAREA     25600 non-null  object
#  5   BPLCNM       26545 non-null  object
#  6   X            26545 non-null  float64
#  7   Y            26545 non-null  float64
#  8   region       26545 non-null  object
#  9   ADDR         26545 non-null  object
#  10  JIGA         26545 non-null  int64
#  11  op_op        26545 non-null  int64
#  12  op_op_12     26545 non-null  int64
#  13  op_op_6      26545 non-null  int64
#  14  op_op_3      26545 non-null  int64
#  15  op_cl        26545 non-null  int64
#  16  op_cl_12     26545 non-null  int64
#  17  op_cl_6      26545 non-null  int64
#  18  op_cl_3      26545 non-null  int64
#  19  cl_op        26545 non-null  int64
#  20  cl_op_12     26545 non-null  int64
#  21  cl_op_6      26545 non-null  int64
#  22  cl_op_3      26545 non-null  int64
#  23  cl_cl        26545 non-null  int64
#  24  cl_cl_12     26545 non-null  int64
#  25  cl_cl_6      26545 non-null  int64
#  26  cl_cl_3      26545 non-null  int64
#  27  region_2     26545 non-null  object
#  28  계            26545 non-null  object
#  29  0~4세         26545 non-null  object
#  30  5~9세         26545 non-null  object
#  31  10~14세       26545 non-null  object
#  32  15~19세       26545 non-null  object
#  33  20~24세       26545 non-null  object
#  34  25~29세       26545 non-null  object
#  35  30~34세       26545 non-null  object
#  36  35~39세       26545 non-null  object
#  37  40~44세       26545 non-null  object
#  38  45~49세       26545 non-null  object
#  39  50~54세       26545 non-null  object
#  40  55~59세       26545 non-null  object
#  41  60~64세       26545 non-null  object
#  42  65~69세       26545 non-null  object
#  43  70~74세       26545 non-null  object
#  44  75~79세       26545 non-null  object
#  45  80~84세       26545 non-null  object
#  46  85~89세       26545 non-null  int64
#  47  90~94세       26545 non-null  int64
#  48  95~99세       26545 non-null  int64
#  49  100세 이상      26525 non-null  object
#  50  num_sw8      26545 non-null  int64
#  51  sw8_name     26545 non-null  object
#  52  sw8_dist     26545 non-null  object
#  53  at4          26545 non-null  int64
#  54  po3          26545 non-null  int64
#  55  num_unv      26545 non-null  int64
#  56  unv_name     26545 non-null  object
#  57  unv_dist     26545 non-null  object
# dtypes: float64(2), int64(25), object(31)
# memory usage: 11.7+ MB

# %%
df = df.loc[df['구'] == '동작구']

# %%
date = df['연도'].astype(str) + '.' + df['월'].astype(str)
df.insert(0,'Date',date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 300 to 359
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    60 non-null     object
#  1   구       60 non-null     object
#  2   연도      60 non-null     int64
#  3   월       60 non-null     int64
#  4   폐업      60 non-null     int64
#  5   영업      60 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 3.3+ KB

# %%
df
# Out:
#         Date    구    연도   월  폐업   영업
# 300   2017.1  동작구  2017   1   4  753
# 301   2017.2  동작구  2017   2   4  749
# 302   2017.3  동작구  2017   3   4  745
# 303   2017.4  동작구  2017   4   6  739
# 304   2017.5  동작구  2017   5   4  735
# 305   2017.6  동작구  2017   6  13  722
# 306   2017.7  동작구  2017   7   4  718
# 307   2017.8  동작구  2017   8   4  714
# 308   2017.9  동작구  2017   9   3  711
# 309  2017.10  동작구  2017  10   5  706
# 310  2017.11  동작구  2017  11   3  703
# 311  2017.12  동작구  2017  12   3  700
# 312   2018.1  동작구  2018   1   1  756
# 313   2018.2  동작구  2018   2   3  753
# 314   2018.3  동작구  2018   3   5  748
# 315   2018.4  동작구  2018   4  10  738
# 316   2018.5  동작구  2018   5   4  734
# 317   2018.6  동작구  2018   6   2  732
# 318   2018.7  동작구  2018   7   8  724
# 319   2018.8  동작구  2018   8   2  722
# 320   2018.9  동작구  2018   9   2  720
# 321  2018.10  동작구  2018  10   3  717
# 322  2018.11  동작구  2018  11   4  713
# 323  2018.12  동작구  2018  12   6  707
# 324   2019.1  동작구  2019   1   5  752
# 325   2019.2  동작구  2019   2   3  749
# 326   2019.3  동작구  2019   3   2  747
# 327   2019.4  동작구  2019   4   5  742
# 328   2019.5  동작구  2019   5   5  737
# 329   2019.6  동작구  2019   6   2  735
# 330   2019.7  동작구  2019   7   1  734
# 331   2019.8  동작구  2019   8   5  729
# 332   2019.9  동작구  2019   9   9  720
# 333  2019.10  동작구  2019  10  11  709
# 334  2019.11  동작구  2019  11   7  702
# 335  2019.12  동작구  2019  12   5  697
# 336   2020.1  동작구  2020   1   5  752
# 337   2020.2  동작구  2020   2   2  750
# 338   2020.3  동작구  2020   3   6  744
# 339   2020.4  동작구  2020   4   8  736
# 340   2020.5  동작구  2020   5   1  735
# 341   2020.6  동작구  2020   6   3  732
# 342   2020.7  동작구  2020   7   3  729
# 343   2020.8  동작구  2020   8   3  726
# 344   2020.9  동작구  2020   9   1  725
# 345  2020.10  동작구  2020  10   8  717
# 346  2020.11  동작구  2020  11   5  712
# 347  2020.12  동작구  2020  12  46  666
# 348   2021.1  동작구  2021   1   5  752
# 349   2021.2  동작구  2021   2   4  748
# 350   2021.3  동작구  2021   3   4  744
# 351   2021.4  동작구  2021   4   2  742
# 352   2021.5  동작구  2021   5   5  737
# 353   2021.6  동작구  2021   6   4  733
# 354   2021.7  동작구  2021   7   4  729
# 355   2021.8  동작구  2021   8   6  723
# 356   2021.9  동작구  2021   9   2  721
# 357  2021.10  동작구  2021  10   0  721
# 358  2021.11  동작구  2021  11   0  721
# 359  2021.12  동작구  2021  12   0  721

# %%
fig, ax1 = plt.subplots()
ax1 = plt.plot(df['Date'],df['폐업'])
plt.title('동작구 폐업',fontproperties=fontprop)
plt.show()

# %%
dj = pd.read_csv('./data/dj_covidm.csv')

# %%
date = dj['Year'].astype(str) + '.' + dj['Month'].astype(str)
dj.insert(0,'Date',date)

# %%
dj
# Out:
#        Date  Unnamed: 0  Year  Month  confirmed  confirmedadd
# 0    2020.2           0  2020      2          1             1
# 1    2020.3           1  2020      3         22            23
# 2    2020.4           2  2020      4          8            31
# 3    2020.5           3  2020      5          9            40
# 4    2020.6           4  2020      6         13            53
# 5    2020.7           5  2020      7         17            70
# 6    2020.8           6  2020      8        105           175
# 7    2020.9           7  2020      9         59           234
# 8   2020.10           8  2020     10         28           262
# 9   2020.11           9  2020     11        124           386
# 10  2020.12          10  2020     12        406           792
# 11   2021.1          11  2021      1        215          1007
# 12   2021.2          12  2021      2        150          1157
# 13   2021.3          13  2021      3        172          1329
# 14   2021.4          14  2021      4        275          1604
# 15   2021.5          15  2021      5        220          1824
# 16   2021.6          16  2021      6        220          2044
# 17   2021.7          17  2021      7        726          2770
# 18   2021.8          18  2021      8        674          3444
# 19   2021.9          19  2021      9        705          4149

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#        Date    구    연도   월  폐업   영업
# 0    2017.1  동작구  2017   1   4  753
# 1    2017.2  동작구  2017   2   4  749
# 2    2017.3  동작구  2017   3   4  745
# 3    2017.4  동작구  2017   4   6  739
# 4    2017.5  동작구  2017   5   4  735
# 5    2017.6  동작구  2017   6  13  722
# 6    2017.7  동작구  2017   7   4  718
# 7    2017.8  동작구  2017   8   4  714
# 8    2017.9  동작구  2017   9   3  711
# 9   2017.10  동작구  2017  10   5  706
# 10  2017.11  동작구  2017  11   3  703
# 11  2017.12  동작구  2017  12   3  700
# 12   2018.1  동작구  2018   1   1  756
# 13   2018.2  동작구  2018   2   3  753
# 14   2018.3  동작구  2018   3   5  748
# 15   2018.4  동작구  2018   4  10  738
# 16   2018.5  동작구  2018   5   4  734
# 17   2018.6  동작구  2018   6   2  732
# 18   2018.7  동작구  2018   7   8  724
# 19   2018.8  동작구  2018   8   2  722
# 20   2018.9  동작구  2018   9   2  720
# 21  2018.10  동작구  2018  10   3  717
# 22  2018.11  동작구  2018  11   4  713
# 23  2018.12  동작구  2018  12   6  707
# 24   2019.1  동작구  2019   1   5  752
# 25   2019.2  동작구  2019   2   3  749
# 26   2019.3  동작구  2019   3   2  747
# 27   2019.4  동작구  2019   4   5  742
# 28   2019.5  동작구  2019   5   5  737
# 29   2019.6  동작구  2019   6   2  735
# 30   2019.7  동작구  2019   7   1  734
# 31   2019.8  동작구  2019   8   5  729
# 32   2019.9  동작구  2019   9   9  720
# 33  2019.10  동작구  2019  10  11  709
# 34  2019.11  동작구  2019  11   7  702
# 35  2019.12  동작구  2019  12   5  697
# 36   2020.1  동작구  2020   1   5  752
# 37   2020.2  동작구  2020   2   2  750
# 38   2020.3  동작구  2020   3   6  744
# 39   2020.4  동작구  2020   4   8  736
# 40   2020.5  동작구  2020   5   1  735
# 41   2020.6  동작구  2020   6   3  732
# 42   2020.7  동작구  2020   7   3  729
# 43   2020.8  동작구  2020   8   3  726
# 44   2020.9  동작구  2020   9   1  725
# 45  2020.10  동작구  2020  10   8  717
# 46  2020.11  동작구  2020  11   5  712
# 47  2020.12  동작구  2020  12  46  666
# 48   2021.1  동작구  2021   1   5  752
# 49   2021.2  동작구  2021   2   4  748
# 50   2021.3  동작구  2021   3   4  744
# 51   2021.4  동작구  2021   4   2  742
# 52   2021.5  동작구  2021   5   5  737
# 53   2021.6  동작구  2021   6   4  733
# 54   2021.7  동작구  2021   7   4  729
# 55   2021.8  동작구  2021   8   6  723
# 56   2021.9  동작구  2021   9   2  721
# 57  2021.10  동작구  2021  10   0  721
# 58  2021.11  동작구  2021  11   0  721
# 59  2021.12  동작구  2021  12   0  721

# %%
seoul_conf = pd.read_csv('./data/seoul_conf.csv')

# %%
seoul_conf = seoul_conf.drop(['Unnamed: 0'],axis=1)

# %%
date = seoul_conf['Year'].astype(str) + '.' + seoul_conf['Month'].astype(str)
seoul_conf.insert(0,'Date',date)

# %%
seoul_conf
# Out:
#        Date  Year  Month  confirmed  confirmedadd
# 0    2020.2  2020      2         82            82
# 1    2020.3  2020      3        372           454
# 2    2020.4  2020      4        179           633
# 3    2020.5  2020      5        228           861
# 4    2020.6  2020      6        452          1313
# 5    2020.7  2020      7        288          1601
# 6    2020.8  2020      8       2314          3915
# 7    2020.9  2020      9       1379          5294
# 8   2020.10  2020     10        718          6012
# 9   2020.11  2020     11       2795          8807
# 10  2020.12  2020     12      10222         19029
# 11   2021.1  2021      1       5133         24162
# 12   2021.2  2021      2       4068         28230
# 13   2021.3  2021      3       3801         32031
# 14   2021.4  2021      4       5806         37837
# 15   2021.5  2021      5       6080         43917
# 16   2021.6  2021      6       6070         49987
# 17   2021.7  2021      7      14372         64359
# 18   2021.8  2021      8      14995         79354
# 19   2021.9  2021      9      21141        100495

# %%
fig, ax1 = plt.subplots()
ax1 = fig.add_subplot() ## axes 생성


#동작구 확진자 수
color1 = 'orange'
ax1.plot(dj['Date'],dj['confirmed'], color=color1, linewidth=2)
ax1.tick_params(axis='y', labelcolor=color1)

#동작구 폐업가게 수
color2 = 'skyblue'
ax2 = ax1.twinx()
ax2.plot(df.iloc[37:57,:]['Date'],df.iloc[37:57,:]['폐업'], color=color2, linewidth=2)  
ax2.tick_params(axis='y', labelcolor=color2)

#서울 확진자 수
color3 = 'pink'
ax3 = ax2.twinx()
ax3.plot(seoul_conf['Date'],seoul_conf['confirmed'], color=color3, linewidth=2)
ax3.tick_params(axis='y', labelcolor=color3)

plt.vlines('2020.2', 0, 25000, color='green', linestyle='--', linewidth=1)  #사회적 거리두기 권고
plt.vlines('2020.8', 0, 25000, color='green', linestyle='--', linewidth=1)  #사회적 거리두기 2단계
plt.vlines('2020.10', 0, 25000, color='green', linestyle='--', linewidth=1)  #사회적 거리두기 1단계
plt.vlines('2020.11', 0, 25000, color='green', linestyle='--', linewidth=1)  #사회적 거리두기 1.5단계
plt.vlines('2020.12', 0, 25000, color='green', linestyle='--', linewidth=1)  #사회적 거리두기 2단계(카페 착석금지)
plt.vlines('2020.12', 0, 25000, color='red', linestyle='--', linewidth=1)  #사회적 거리두기 2.5단계(5인이상 집합금지, 카페착석금지)
plt.vlines('2021.2', 0, 25000, color='green', linestyle='--', linewidth=1)  #사회적 거리두기 2단계(5인이상 집합금지, 카페 22시 이후 포장/배달만)
plt.vlines('2021.2', 0, 25000, color='green', linestyle='--', linewidth=1)  #사회적 거리두기 4단계(5인이상 집합금지, 카페 22시 이후 포장/배달만)


plt.show()

# %%
#vline 거리두기단계

# %%
전국확진자, 서울시 확진자, 동작구 확진자, 수도권거리두기단계,
