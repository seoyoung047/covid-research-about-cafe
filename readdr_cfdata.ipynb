# %%
import requests
import json
import pandas as pd
import datetime as dt
import numpy as np

# %%
cfdata = pd.read_csv('./data/cfdata.csv')
cfdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24541 entries, 0 to 24540
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   24541 non-null  int64
#  1   APVPERMYMD   24541 non-null  object
#  2   TRDSTATEGBN  24541 non-null  int64
#  3   TRDSTATENM   24541 non-null  object
#  4   DCBYMD       8624 non-null   object
#  5   SITEAREA     23486 non-null  object
#  6   BPLCNM       24541 non-null  object
#  7   X            24541 non-null  float64
#  8   Y            24541 non-null  float64
#  9   region       24541 non-null  object
#  10  ADDR         24541 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 2.1+ MB

# %%
new_add=[]

for i in range(len(cfdata['RDNWHLADDR'])):
    new_add.append(cfdata['RDNWHLADDR'][i].split(',')[0])

print(len(new_add))
print(len(cfdata['RDNWHLADDR']))

# %%
cfdata['ADDR'] = new_add

# %%
#cfdata = cfdata.drop(['Unnamed: 0'],axis=1)
#cfdata = cfdata.drop(['RDNWHLADDR'],axis=1)

# %%
cfdata[25]

# %%
cfdata.to_csv('./data/cfdata.csv',encoding='utf-8')

# %%
cfdata['ADDR'][0]
# Out:
# '서울특별시 강동구 양재대로87길 11 (성내동)'

# %%
import re

# %%
#p = re.compile('^"("\w')

# %%
#p.findall(cfdata['ADDR'][0])

# %%
new_addr=[]

for i in range(len(cfdata['ADDR'])):
    new_addr.append(cfdata['ADDR'][i].split('(')[0])

print(len(new_addr))
print(len(cfdata['ADDR']))
# Out:
# 24541
# 24541

# %%
cfdata['ADDR'] = new_addr

# %%
cfdata
# Out:
#        Unnamed: 0  APVPERMYMD  TRDSTATEGBN TRDSTATENM      DCBYMD SITEAREA  \
# 0               0  2013-11-13            3         폐업  2017-10-11    22.53
# 1               1  2015-07-08            3         폐업  2017-07-10    22.00
# 2               2  2014-03-20            3         폐업  2017-07-17    74.21
# 3               3  2014-12-05            3         폐업  2017-06-02   337.19
# 4               4  2013-01-03            3         폐업  2017-05-18    30.00
# ...           ...         ...          ...        ...         ...      ...
# 24536       24536  2011-03-02            1      영업/정상         NaN    98.10
# 24537       24537  2010-09-16            1      영업/정상         NaN    50.00
# 24538       24538  2010-05-27            1      영업/정상         NaN   142.50
# 24539       24539  2009-10-29            1      영업/정상         NaN    62.00
# 24540       24540  2013-12-20            1      영업/정상         NaN    66.84
#
# ...

# %%
cfdata = cfdata.drop(['Unnamed: 0'],axis=1)

# %%
cfdata
# Out:
#        APVPERMYMD  TRDSTATEGBN TRDSTATENM      DCBYMD SITEAREA  \
# 0      2013-11-13            3         폐업  2017-10-11    22.53
# 1      2015-07-08            3         폐업  2017-07-10    22.00
# 2      2014-03-20            3         폐업  2017-07-17    74.21
# 3      2014-12-05            3         폐업  2017-06-02   337.19
# 4      2013-01-03            3         폐업  2017-05-18    30.00
# ...           ...          ...        ...         ...      ...
# 24536  2011-03-02            1      영업/정상         NaN    98.10
# 24537  2010-09-16            1      영업/정상         NaN    50.00
# 24538  2010-05-27            1      영업/정상         NaN   142.50
# 24539  2009-10-29            1      영업/정상         NaN    62.00
# 24540  2013-12-20            1      영업/정상         NaN    66.84
#
#                 BPLCNM           X          Y region                     ADDR
# 0              탭플레이 커피  127.134306  37.525438    강동구    서울특별시 강동구 양재대로87길 11
# ...

# %%
cfdata.to_csv('./data/cfdata.csv',encoding='utf-8')
