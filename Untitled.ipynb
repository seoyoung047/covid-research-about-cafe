# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cfdata = pd.read_csv('./data/cfdata.csv')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
cfdata
# Out:
#        Unnamed: 0  APVPERMYMD  TRDSTATEGBN TRDSTATENM      DCBYMD SITEAREA  \
# 0               0  2013-11-13            3         폐업  2017-10-11    22.53
# 1               1  2015-07-08            3         폐업  2017-07-10    22.00
# 2               2  2014-03-20            3         폐업  2017-07-17    74.21
# 3               3  2014-12-05            3         폐업  2017-06-02   337.19
# 4               4  2013-01-03            3         폐업  2017-05-18    30.00
# ...           ...         ...          ...        ...         ...      ...
# 24536       24536  2011-03-02            1      영업/정상         NaN     98.1
# 24537       24537  2010-09-16            1      영업/정상         NaN       50
# 24538       24538  2010-05-27            1      영업/정상         NaN    142.5
# 24539       24539  2009-10-29            1      영업/정상         NaN       62
# 24540       24540  2013-12-20            1      영업/정상         NaN    66.84
#
# ...

# %%
cfdata.columns
# Out:
# Index(['Unnamed: 0', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DCBYMD',
#        'SITEAREA', 'BPLCNM', 'X', 'Y', 'region', 'ADDR', 'JIGA', 'at4', 'po3',
#        'num_unv', 'unv_name', 'unv_dist', 'region_2', '계', '0~4세', '5~9세',
#        '10~14세', '15~19세', '20~24세', '25~29세', '30~34세', '35~39세', '40~44세',
#        '45~49세', '50~54세', '55~59세', '60~64세', '65~69세', '70~74세', '75~79세',
#        '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상', 'op_op', 'op_op_12',
#        'op_op_6', 'op_op_3', 'op_cl', 'op_cl_12', 'op_cl_6', 'op_cl_3',
#        'cl_op', 'cl_op_12', 'cl_op_6', 'cl_op_3', 'cl_cl', 'cl_cl_12',
#        'cl_cl_6', 'cl_cl_3'],
#       dtype='object')

# %%
cfdata_1 = cfdata.drop(['Unnamed: 0','TRDSTATENM','DCBYMD','BPLCNM','X','Y','region','ADDR','unv_name','region_2'],axis = 1)
cfdata_2 = cfdata_1.drop(['0~4세', '5~9세','10~14세', '15~19세', '20~24세', '25~29세', '30~34세', '35~39세', '40~44세','45~49세', '50~54세', '55~59세',
                         '60~64세', '65~69세', '70~74세', '75~79세','80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],axis=1)

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data=cfdata_2.corr(), annot=True, fmt='.2f', linewidths=.5)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>
