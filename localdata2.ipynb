# %%
#서울특별시 휴게음식점 인허가 정보

import urllib.request 
import json 
import pandas as pd 
from pandas.io.json import json_normalize

# %%
a=1
b=1000

df_mine = pd.DataFrame(columns=['APVPERMYMD','TRDSTATEGBN','TRDSTATENM','DCBYMD','SITEAREA','RDNWHLADDR','BPLCNM','UPTAENM','X','Y'])

while b < 110000 :
    url='http://openapi.seoul.go.kr:8088/5050435353726e643637446f4f5774/json/LOCALDATA_072405/'+str(a)+'/'+str(b)
    response = urllib.request.urlopen(url)
    json_str = response.read().decode("utf-8")
    json_object = json.loads(json_str)
    df = pd.json_normalize(json_object['LOCALDATA_072405']['row'])
    
    df_sel = df[['APVPERMYMD','TRDSTATEGBN','TRDSTATENM','DCBYMD','SITEAREA','RDNWHLADDR','BPLCNM','UPTAENM','X','Y']]
    
    df_mine = pd.concat([df_sel,df_mine])
    
    
    a = a + 1000
    b = b + 1000 
    
df_mine
# Out:
#     APVPERMYMD TRDSTATEGBN TRDSTATENM    DCBYMD SITEAREA  \
# 0     20190530          01      영업/정상              23.55
# 1     20180919          03         폐업  20201204    16.38
# 2     20141022          01      영업/정상              34.00
# 3     20130612          01      영업/정상              14.60
# 4     20120523          03         폐업  20201204    42.18
# ..         ...         ...        ...       ...      ...
# 995   19680219          03         폐업  19970131
# 996   20110421          01      영업/정상
# 997   20110425          01      영업/정상
# 998   20111006          01      영업/정상
# 999   20111006          01      영업/정상
#
#                                         RDNWHLADDR           BPLCNM   UPTAENM  \
# 0                 서울특별시 중구 통일로 92, 케이지타워 20층 (순화동)  CAFE KG(카페 케이지)  기타 휴게음식점
# 1        서울특별시 강서구 금낭화로 135, 금강프라자빌딩 1층 109호 (방화동)         홍루이젠 방화점    일반조리판매
# 2             서울특별시 용산구 원효로 268, 지상1층 101호 (원효로1가)             카페맑음       커피숍
# 3     서울특별시 용산구 청파로 378 (동자동, 43-227 서울역 지상2층 10번)             라망스콘     철도역구내
# 4     서울특별시 용산구 소월로20길 64 (용산동2가, 5-1117외1필지 지상1층)           메밀&샐러드  기타 휴게음식점
# ..                                             ...              ...       ...
# 995                                                             황태자        다방
# 996                  서울특별시 종로구 지봉로 89 (창신동,(지상1층))             작은나무       커피숍
# 997                       서울특별시 종로구 율곡로 280 (종로6가)         한솥(동대문점)    일반조리판매
# 998                                                 마노핀익스프레스 종로3가역점  기타 휴게음식점
# 999  서울특별시 종로구 사직로 지하 130 (적선동,지하철 3호선 경복궁역 가 매표소)   마노핀익스프레스 경복궁역점  기타 휴게음식점
#
#                         X                     Y
# 0        197214.205778633      451259.671938774
# 1        183366.101249557      452817.469477897
# 2        197308.865165056      448745.657720825
# 3        197255.617985125      450139.846002725
# 4        198533.740282294      449083.810613623
# ..                    ...                   ...
# 995
# 996  201271.380167374      452868.306559671
# 997  200613.644778077      452243.942715216
# 998
# 999  197563.535801544      452607.767361081
#
# [108653 rows x 10 columns]

# %%
df_mine.to_csv('./data/data2.csv')
