# %%
import requests
import json
import pandas as pd
import datetime as dt
import numpy as np

# %%
cfdata = pd.read_csv('./data/cfdata.csv')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#서울 중구 한강대로 405 (서울역)
url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+ '서울 중구 한강대로 405'
headers = {"Authorization": "KakaoAK 6341d1e76477fbac498a469adc87108d"}
result = json.loads(str(requests.get(url, headers=headers).text))
#result['documents']

# %%
date = pd.to_datetime(cfdata['DCBYMD'],format='%Y-%m-%d')
opdate = pd.to_datetime(cfdata['APVPERMYMD'],format='%Y-%m-%d')
cfdata['DCBYMD'] = date
cfdata['APVPERMYMD'] = opdate
cfdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26545 entries, 0 to 26544
# Data columns (total 59 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   26545 non-null  int64
#  1   APVPERMYMD   26545 non-null  datetime64[ns]
#  2   TRDSTATEGBN  26545 non-null  int64
#  3   TRDSTATENM   26545 non-null  object
#  4   DCBYMD       10145 non-null  datetime64[ns]
#  5   SITEAREA     25600 non-null  object
#  6   BPLCNM       26545 non-null  object
#  7   X            26545 non-null  float64
#  8   Y            26545 non-null  float64
#  9   region       26545 non-null  object
#  10  ADDR         26545 non-null  object
#  11  JIGA         26545 non-null  int64
#  12  op_op        26545 non-null  int64
#  13  op_op_12     26545 non-null  int64
#  14  op_op_6      26545 non-null  int64
#  15  op_op_3      26545 non-null  int64
#  16  op_cl        26545 non-null  int64
#  17  op_cl_12     26545 non-null  int64
# ...

# %%
cfdata = cfdata.drop(['Unnamed: 0'],axis = 1)
open_ing = cfdata[cfdata['TRDSTATEGBN']==1]
#cf = closed[closed['DCBYMD'].dt.month ==12]
#cf = cf[cf['DCBYMD'].dt.year == 2020]
dongjak = open_ing[open_ing['region']=='동작구']
name = open_ing['BPLCNM']
name = name.reset_index(drop=True)
dongjak = dongjak.reset_index(drop=True)
dongjak
# Out:
#     APVPERMYMD  TRDSTATEGBN TRDSTATENM DCBYMD SITEAREA    BPLCNM           X  \
# 0   2021-08-11            1      영업/정상    NaT    29.09      750M  126.953539
# 1   2016-07-08            1      영업/정상    NaT     6.44    니토로스터스  126.924239
# 2   2020-07-13            1      영업/정상    NaT    18.89      모코커피  126.945124
# 3   2021-07-16            1      영업/정상    NaT    21.56       마이빈  126.962445
# 4   2016-06-28            1      영업/정상    NaT    33.93      선한이웃  126.913552
# ..         ...          ...        ...    ...      ...       ...         ...
# 458 2011-11-18            1      영업/정상    NaT       33  아마스빈중앙대점  126.959401
# 459 2011-07-28            1      영업/정상    NaT    24.79      꼬치박스  126.980682
# 460 2012-05-21            1      영업/정상    NaT       18        미모  126.936854
# 461 2010-10-07            1      영업/정상    NaT     5.17      커피자리  126.943922
# 462 2013-07-31            1      영업/정상    NaT   206.82   커피하우스 준  126.975089
#
# ...

# %%
open_ing.to_csv('./data/open_ing.csv',encoding='utf-8')

# %%
dongjak['SITEAREA']=dongjak['SITEAREA'].astype('float')
dongjak.info()
#a=dongjak2020[dongjak2020['SITEAREA']>100]
#a.hist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 58 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   APVPERMYMD   463 non-null    datetime64[ns]
#  1   TRDSTATEGBN  463 non-null    int64
#  2   TRDSTATENM   463 non-null    object
#  3   DCBYMD       0 non-null      datetime64[ns]
#  4   SITEAREA     462 non-null    float64
#  5   BPLCNM       463 non-null    object
#  6   X            463 non-null    float64
#  7   Y            463 non-null    float64
#  8   region       463 non-null    object
#  9   ADDR         463 non-null    object
#  10  JIGA         463 non-null    int64
#  11  op_op        463 non-null    int64
#  12  op_op_12     463 non-null    int64
#  13  op_op_6      463 non-null    int64
#  14  op_op_3      463 non-null    int64
#  15  op_cl        463 non-null    int64
#  16  op_cl_12     463 non-null    int64
#  17  op_cl_6      463 non-null    int64
# ...

# %%
#x = dongjak[dongjak.SITEAREA>100]['X']
#y = dongjak[dongjak.SITEAREA>100]['Y']
x = dongjak['X']
y = dongjak['Y']
x=x.reset_index(drop=True)
y=y.reset_index(drop=True)

# %%
#!pip install folium
import folium

# %%
Map = folium.Map(location=[37.500881,126.953083], zoom_start=14)

for i in range(len(x)):
    center = [y[i],x[i]] 
    folium.Marker(location = center, tooltip = name[i]).add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
dongjak.iloc[100:,[5,8,9,27]]
# Out:
#          BPLCNM region                      ADDR region_2
# 100        모코커피    동작구         서울특별시 동작구 대방동길 57      대방동
# 101        커피중독    동작구       서울특별시 동작구 동작대로7길 65     사당1동
# 102        카페디차    동작구         서울특별시 동작구 만양로 56     노량진1동
# 103  스타벅스 이수자이점    동작구         서울특별시 동작구 사당로 300     사당1동
# 104    이디야커피사당점    동작구         서울특별시 동작구 동작대로 45     사당1동
# ..          ...    ...                       ...      ...
# 458    아마스빈중앙대점    동작구         서울특별시 동작구 흑석로 88       흑석동
# 459        꼬치박스    동작구  서울특별시 동작구 동작대로27가길 46-5      사당2동
# 460          미모    동작구        서울특별시 동작구 상도로 161      상도2동
# 461        커피자리    동작구       서울특별시 동작구 노량진로 162     노량진1동
# 462     커피하우스 준    동작구      서울특별시 동작구 사당로 247-7      사당3동
#
# [363 rows x 4 columns]

# %%
dongjak.columns
# Out:
# Index(['APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DCBYMD', 'SITEAREA',
#        'BPLCNM', 'X', 'Y', 'region', 'ADDR', 'JIGA', 'op_op', 'op_op_12',
#        'op_op_6', 'op_op_3', 'op_cl', 'op_cl_12', 'op_cl_6', 'op_cl_3',
#        'cl_op', 'cl_op_12', 'cl_op_6', 'cl_op_3', 'cl_cl', 'cl_cl_12',
#        'cl_cl_6', 'cl_cl_3', 'region_2', '계', '0~4세', '5~9세', '10~14세',
#        '15~19세', '20~24세', '25~29세', '30~34세', '35~39세', '40~44세', '45~49세',
#        '50~54세', '55~59세', '60~64세', '65~69세', '70~74세', '75~79세', '80~84세',
#        '85~89세', '90~94세', '95~99세', '100세 이상', 'num_sw8', 'sw8_name',
#        'sw8_dist', 'at4', 'po3', 'num_unv', 'unv_name', 'unv_dist'],
#       dtype='object')

# %%
list1 = dongjak[dongjak['num_sw8'] > 1]

# %%
list1
# Out:
#     APVPERMYMD  TRDSTATEGBN TRDSTATENM DCBYMD  SITEAREA    BPLCNM           X  \
# 0   2021-08-11            1      영업/정상    NaT     29.09      750M  126.953539
# 1   2016-07-08            1      영업/정상    NaT      6.44    니토로스터스  126.924239
# 2   2020-07-13            1      영업/정상    NaT     18.89      모코커피  126.945124
# 4   2016-06-28            1      영업/정상    NaT     33.93      선한이웃  126.913552
# 5   2020-11-24            1      영업/정상    NaT     11.00       루바토  126.979776
# ..         ...          ...        ...    ...       ...       ...         ...
# 458 2011-11-18            1      영업/정상    NaT     33.00  아마스빈중앙대점  126.959401
# 459 2011-07-28            1      영업/정상    NaT     24.79      꼬치박스  126.980682
# 460 2012-05-21            1      영업/정상    NaT     18.00        미모  126.936854
# 461 2010-10-07            1      영업/정상    NaT      5.17      커피자리  126.943922
# 462 2013-07-31            1      영업/정상    NaT    206.82   커피하우스 준  126.975089
#
# ...

# %%
x1 = list1['X']
y1 = list1['Y']
x1 = x1.reset_index(drop=True)
y1 = y1.reset_index(drop=True)

# %%
x1
# Out:
# 0      126.953539
# 1      126.924239
# 2      126.945124
# 3      126.913552
# 4      126.979776
#           ...
# 407    126.959401
# 408    126.980682
# 409    126.936854
# 410    126.943922
# 411    126.975089
# Name: X, Length: 412, dtype: float64

# %%
Map = folium.Map(location=[37.500881,126.953083], zoom_start=14)

for i in range(len(x1)):
    center = [y1[i],x1[i]] 
    folium.Marker(location = center, tooltip = name[i]).add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#cfdata = cfdata.drop(['Unnamed: 0'],axis = 1)
closed = cfdata[cfdata['TRDSTATEGBN']==3]
#cf = closed[closed['DCBYMD'].dt.month ==12]
#cf = cf[cf['DCBYMD'].dt.year == 2020]
cl_dongjak = closed[closed['region']=='동작구']
name2 = closed['BPLCNM']
name2 = name2.reset_index(drop=True)
cl_dongjak = cl_dongjak.reset_index(drop=True)
cl_dongjak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 58 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   APVPERMYMD   294 non-null    datetime64[ns]
#  1   TRDSTATEGBN  294 non-null    int64
#  2   TRDSTATENM   294 non-null    object
#  3   DCBYMD       294 non-null    datetime64[ns]
#  4   SITEAREA     294 non-null    object
#  5   BPLCNM       294 non-null    object
#  6   X            294 non-null    float64
#  7   Y            294 non-null    float64
#  8   region       294 non-null    object
#  9   ADDR         294 non-null    object
#  10  JIGA         294 non-null    int64
#  11  op_op        294 non-null    int64
#  12  op_op_12     294 non-null    int64
#  13  op_op_6      294 non-null    int64
#  14  op_op_3      294 non-null    int64
#  15  op_cl        294 non-null    int64
#  16  op_cl_12     294 non-null    int64
#  17  op_cl_6      294 non-null    int64
# ...

# %%
x2 = cl_dongjak['X']
y2 = cl_dongjak['Y']
x2 = x2.reset_index(drop=True)
y2 = y2.reset_index(drop=True)

# %%
Map2 = folium.Map(location=[37.500881,126.953083], zoom_start=14)

for i in range(len(x2)):
    center = [y2[i],x2[i]] 
    folium.Marker(location = center, tooltip = name2[i]).add_to(Map2)
Map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
closed = cfdata[cfdata['TRDSTATEGBN']==3]
cf = closed[closed['DCBYMD'].dt.month ==12]
cf = cf[cf['DCBYMD'].dt.year == 2020]
cl12_dongjak = closed[closed['region']=='동작구']
name12 = cl12_dongjak['BPLCNM']
name12 = name12.reset_index(drop=True)
cl12_dongjak = cl12_dongjak.reset_index(drop=True)

x12 = cl12_dongjak['X']
y12 = cl12_dongjak['Y']
x12=x12.reset_index(drop=True)
y12=y12.reset_index(drop=True)

# %%
Map3 = folium.Map(location=[37.500881,126.953083], zoom_start=14)

for i in range(len(x12)):
    center = [y12[i],x12[i]] 
    folium.Marker(location = center, tooltip = name12[i]).add_to(Map3)
Map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
dongjak2017 = cf_dj[cf_dj['DCBYMD'].dt.year == 2017]
name = dongjak2017['BPLCNM']
name = name.reset_index(drop=True)
dongjak2017 = dongjak2017.reset_index(drop=True)
x = dongjak2017['X']
y = dongjak2017['Y']
x=x.reset_index(drop=True)
y=y.reset_index(drop=True)

# %%
Map4 = folium.Map(location=[37.500881,126.953083], zoom_start=14)

for i in range(50):
    center = [y[i],x[i]] 
    folium.Marker(location = center, tooltip = name[i]).add_to(Map4)
Map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
